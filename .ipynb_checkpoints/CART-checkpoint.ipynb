# %%
import numpy as np
import pandas as pd

# %%
import os
import sys

# %%
print(f"python version : {sys.version_info.major}.{sys.version_info.minor}.{sys.version_info.micro}",)

print("np version : ", np.__version__)
print("pd version : ",pd.__version__)
# Out:
# python version : 3.8.10
# np version :  1.24.3
# pd version :  2.0.3

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  'CART.ipynb',
#  'data',
#  'README.md',
#  'trained_model',
#  'venv']

# %%
os.listdir("data/h&m/")
# Out:
# ['articles.parquet', 'customers.parquet', 'transactions_train.csv']

# %% [markdown]
# Goal: predict article for each customer for next 7 days

# %%
interaction_df = pd.read_csv("data/h&m/transactions_train.csv")
user_df = pd.read_parquet("data/h&m/customers.parquet")
item_df = pd.read_parquet("data/h&m/articles.parquet")

# %% [markdown]
# ## configs

# %%
date_col = 't_dat'
user_col = 'customer_id'
item_col = 'article_id'

# %%
interaction_df[date_col] = pd.to_datetime(interaction_df[date_col], format='%Y-%m-%d')
print(interaction_df.shape)
interaction_df.head()
# Out:
# (31788324, 5)
#        t_dat                                        customer_id  article_id  \
# 0 2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 1 2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   541518023
# 2 2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   505221004
# 3 2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687003
# 4 2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687004
#
#       price  sales_channel_id
# 0  0.050831                 2
# 1  0.030492                 2
# 2  0.015237                 2
# 3  0.016932                 2
# 4  0.016932                 2

# %%
interaction_df.describe()
# Out:
#                                t_dat    article_id         price  \
# count                       31788324  3.178832e+07  3.178832e+07
# mean   2019-09-15 17:27:46.894452992  6.962272e+08  2.782927e-02
# min              2018-09-20 00:00:00  1.087750e+08  1.694915e-05
# 25%              2019-03-28 00:00:00  6.328030e+08  1.581356e-02
# 50%              2019-08-25 00:00:00  7.145820e+08  2.540678e-02
# 75%              2020-03-29 00:00:00  7.865240e+08  3.388136e-02
# max              2020-09-22 00:00:00  9.562170e+08  5.915254e-01
# std                              NaN  1.334480e+08  1.918113e-02
#
#        sales_channel_id
# count      3.178832e+07
# mean       1.704028e+00
# min        1.000000e+00
# 25%        1.000000e+00
# 50%        2.000000e+00
# 75%        2.000000e+00
# max        2.000000e+00
# std        4.564786e-01

# %%
print(user_df.shape)
user_df.head()
# Out:
# (1371980, 7)
#                                          customer_id   FN  Active  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  NaN     NaN
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  NaN     NaN
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  NaN     NaN
# 3  00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...  NaN     NaN
# 4  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...  1.0     1.0
#
#   club_member_status fashion_news_frequency   age  \
# 0             ACTIVE                   NONE  49.0
# 1             ACTIVE                   NONE  25.0
# 2             ACTIVE                   NONE  24.0
# 3             ACTIVE                   NONE  54.0
# 4             ACTIVE              Regularly  52.0
#
#                                          postal_code
# 0  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...
# 1  2973abc54daa8a5f8ccfe9362140c63247c5eee03f1d93...
# 2  64f17e6a330a85798e4998f62d0930d14db8db1c054af6...
# 3  5d36574f52495e81f019b680c843c443bd343d5ca5b1c2...
# 4  25fa5ddee9aac01b35208d01736e57942317d756b32ddd...

# %%
print(item_df.shape)
item_df.head()
# Out:
# (105542, 25)
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 0                     Solid                  9             Black  ...
# 1                     Solid                 10             White  ...
# 2                    Stripe                 11         Off White  ...
# 3                     Solid                  9             Black  ...
# 4                     Solid                 10             White  ...
#
#    department_name index_code        index_name index_group_no  \
# 0     Jersey Basic          A        Ladieswear              1
# 1     Jersey Basic          A        Ladieswear              1
# 2     Jersey Basic          A        Ladieswear              1
# 3   Clean Lingerie          B  Lingeries/Tights              1
# 4   Clean Lingerie          B  Lingeries/Tights              1
#
#    index_group_name section_no            section_name garment_group_no  \
# 0        Ladieswear         16  Womens Everyday Basics             1002
# 1        Ladieswear         16  Womens Everyday Basics             1002
# 2        Ladieswear         16  Womens Everyday Basics             1002
# 3        Ladieswear         61         Womens Lingerie             1017
# 4        Ladieswear         61         Womens Lingerie             1017
#
#    garment_group_name                                        detail_desc
# 0        Jersey Basic            Jersey top with narrow shoulder straps.
# 1        Jersey Basic            Jersey top with narrow shoulder straps.
# 2        Jersey Basic            Jersey top with narrow shoulder straps.
# 3   Under-, Nightwear  Microfibre T-shirt bra with underwired, moulde...
# 4   Under-, Nightwear  Microfibre T-shirt bra with underwired, moulde...
#
# [5 rows x 25 columns]

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Item2Vec

# %%
import gensim

# %%
train_df = interaction_df.loc[interaction_df['t_dat'] < '2020-01-01'].copy()
test_df = interaction_df.loc[interaction_df['t_dat'] < '2020-01-01'].copy()

# %%
train_df.head()
# Out:
#        t_dat                                        customer_id  article_id  \
# 0 2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 1 2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   541518023
# 2 2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   505221004
# 3 2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687003
# 4 2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687004
#
#       price  sales_channel_id
# 0  0.050831                 2
# 1  0.030492                 2
# 2  0.015237                 2
# 3  0.016932                 2
# 4  0.016932                 2

# %%
user_seq = train_df.groupby(user_col)[item_col].apply(list)
user_seq_df = pd.DataFrame(user_seq).rename(columns={item_col:"seq_list"})
tr_seq_df = train_df.drop_duplicates(user_col, keep='first')
tr_seq_df = tr_seq_df.merge(user_seq_df, on=user_col)

# %%
tr_seq_df['n_seq'] = tr_seq_df['seq_list'].str.len()

# %%
tr_seq_df[['n_seq']].hist(bins=100, figsize=(4, 3))
# Out:
# array([[<Axes: title={'center': 'n_seq'}>]], dtype=object)

# %%
tr_seq_df.head()
# Out:
#        t_dat                                        customer_id  article_id  \
# 0 2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 1 2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   505221004
# 2 2018-09-20  00083cda041544b2fbb0e0d2905ad17da7cf1007526fb4...   688873012
# 3 2018-09-20  0008968c0d451dbc5a9968da03196fe20051965edde741...   531310002
# 4 2018-09-20  000aa7f0dc06cd7174389e76c9e132a67860c5f65f9706...   501820043
#
#       price  sales_channel_id  \
# 0  0.050831                 2
# 1  0.015237                 2
# 2  0.030492                 1
# 3  0.022525                 2
# 4  0.016932                 2
#
#                                             seq_list  n_seq
# 0       [663713001, 541518023, 663713001, 578020002]      4
# 1  [505221004, 685687003, 685687004, 685687001, 5...    110
# 2  [688873012, 501323011, 598859003, 688873020, 6...     26
# 3  [531310002, 529841001, 662980002, 496111003, 5...     38
# 4  [501820043, 501820043, 674681001, 671505001, 6...     47

# %%
tr_sequences = tr_seq_df['seq_list'].tolist()

# %%
len(tr_sequences)
# Out:
# 1116877

# %%
from gensim.models import Word2Vec, KeyedVectors
import datetime

model = Word2Vec(vector_size = 100, #
                 workers = 4, # s
                 sg = 1, # 1 = Skip-gram, else = CBOW
                 hs = 0, # Hierachical softmax = 1, else Negative sampling
                 negative = 3, 
                 window = 9999)

# %%
model.build_vocab(tr_sequences, progress_per=10_000)
model.train(tr_sequences, total_examples=model.corpus_count,
           epochs=10)
# Out:
# (207861150, 208081920)

# %%
"""
Store trained word vectors in `KeyedVectors` instance
No need to save model (containing curr state) if no additional training is required.

Keeping only word embedding space makes it more memory efficient
"""
item_vectors = model.wv
item_vectors[663713001] # get item_id's item vector


item_vectors.save("trained_model/item2vec_emb_space.wordvectors")

# %%
item_vectors =  KeyedVectors.load("trained_model/item2vec_emb_space.wordvectors"
                                 , mmap='r' # Load with memory-mapping which is read-only, shared across processes thus faster.
                                 )

# %%
# model.save('trained_model/item2vec.model')
# item2vec = Word2Vec(vector_size=100, workers=4, sg=1, hs=0, negative=5, window=9999999)
# model = item2vec.load('trained_model/item2vec.model')

# %%
model.corpus_count == len(tr_seq_df)
# Out:
# True

# %%
model.corpus_total_words == tr_seq_df['n_seq'].sum()
# Out:
# True

# %%
import umap
cluster_embedding = umap.UMAP(n_neighbors=30, min_dist=0.0,
                              n_components=2, random_state=42).fit_transform(X)
plt.figure(figsize=(10,9))
plt.scatter(cluster_embedding[:, 0], cluster_embedding[:, 1], s=3, cmap='Spectral')

# %%
user_seq = test_df.groupby(user_col)[item_col].apply(list)
user_seq_df = pd.DataFrame(user_seq).rename(columns={item_col:"seq_list"})
test_seq_df = test_df.drop_duplicates(user_col, keep='first')
test_seq_df = test_seq_df.merge(user_seq_df, on=user_col)
test_seq_df['n_seq'] = test_seq_df['seq_list'].str.len()

# filter : n_seq > 3 to use both: item2item, seq(user)2item  
test_seq_df = test_seq_df.loc[test_seq_df['n_seq'] >= 3].copy()
test_seq_df['item2item_input'] = test_seq_df['seq_list'].str[-2]
test_seq_df['seq2item_input'] = test_seq_df['seq_list'].str[:-1]
test_seq_df['true_y'] = test_seq_df['seq_list'].apply(lambda x: x[-1])

# %% [markdown]
# 1. t-1 의 item 만 주고 추천
# 2. 0~t-1 의 모든 item 들을 합하여 user vector 생성후 추천.

# %%
test_seq_df.loc[test_seq_df['n_seq'] < 4].head()
# Out:
#          t_dat                                        customer_id  article_id  \
# 32  2018-09-20  00923f88cda50cbea4c5ceb2bd3467c620a9d74cb7da95...   564786020
# 50  2018-09-20  00cd0391b52a160dce983a43c15a6e1125d082b78dfa21...   598806012
# 135 2018-09-20  025d110f771f9d4bd41abd0fadca58b1be1553c895c7f6...   657891002
# 176 2018-09-20  030654e7a0c6b286996114368a92fd411cfa5f9d4afcbf...   549914002
# 283 2018-09-20  053070ffd27651239c41ad9011888e0b7d9fc0892de672...   633130017
#
#         price  sales_channel_id                           seq_list  n_seq  \
# 32   0.019814                 1  [564786020, 655347002, 655347007]      3
# 50   0.016932                 1  [598806012, 662230001, 654772003]      3
# 135  0.042356                 2  [657891002, 655993002, 655993001]      3
# 176  0.011847                 2  [549914002, 575464004, 702208002]      3
# 283  0.016932                 1  [633130017, 632982021, 712917001]      3
#
#         true_y  item2item_input          seq2item_input
# 32   655347007        655347002  [564786020, 655347002]
# 50   654772003        662230001  [598806012, 662230001]
# 135  655993001        655993002  [657891002, 655993002]
# 176  702208002        575464004  [549914002, 575464004]
# 283  712917001        632982021  [633130017, 632982021]

# %%
test_seq_df['item2item_input']
# Out:
# 0          663713001
# 1          745745001
# 2          716087001
# 3          650279001
# 4          693497001
#              ...
# 1116871    688105010
# 1116872    819547001
# 1116874    636207006
# 1116875    684673002
# 1116876    806973001
# Name: item2item_input, Length: 894040, dtype: int64

# %%
vec = item_vectors[806973001]

# %%
vec
# Out:
# array([-2.85463333e-01, -1.32051483e-01,  1.25760734e-01, -2.50868678e-01,
#        -4.14323330e-01,  3.29669178e-01,  1.04603238e-01, -2.95886457e-01,
#         2.61420369e-01,  2.22846791e-01, -4.08281863e-01,  6.47841752e-01,
#         4.05549118e-03,  1.29330218e-01, -2.72886660e-02, -1.12069674e-01,
#         4.53388020e-02, -4.14711051e-02, -4.44634914e-01,  3.06993723e-01,
#        -8.15803558e-02,  1.25753462e-01, -3.43907438e-02, -5.19639015e-01,
#         8.38181674e-02, -1.75404593e-01,  2.47674614e-01, -2.37918302e-01,
#        -5.69715381e-01,  2.28379518e-01, -9.27271172e-02, -1.09584667e-01,
#         1.04999512e-01, -1.51628092e-01, -3.14620316e-01,  5.51070452e-01,
#         9.76535901e-02,  2.22618058e-01,  2.44108126e-01,  9.13212635e-03,
#        -5.69852173e-01, -1.71641484e-01,  2.54178703e-01, -4.74910378e-01,
#        -2.84055978e-01, -2.61623174e-01,  6.84003234e-02,  4.22255732e-02,
#        -1.20248593e-01, -1.39209434e-01, -3.47197086e-01,  4.08620805e-01,
#        -2.74485171e-01,  2.21453402e-02,  1.81725416e-02,  5.01966238e-01,
#         7.42927799e-03,  2.19284564e-01, -4.10195440e-02,  4.73174900e-02,
#        -2.23700732e-01, -9.30901691e-02,  5.39859124e-02, -8.64089802e-02,
#         1.74607053e-01, -9.34710354e-02, -1.17636643e-01, -8.79913568e-02,
#         1.23437122e-01, -5.10439754e-01,  6.18695855e-01,  1.26706421e-01,
#        -6.49152920e-02, -2.91151762e-01, -1.98330402e-01,  1.44163612e-02,
#        -2.72958755e-01, -2.76279300e-01, -3.28161456e-02,  3.87636900e-01,
#         9.39407945e-02, -2.44722907e-02,  5.13171137e-04,  4.64303106e-01,
#        -2.57335186e-01, -2.03173161e-01, -1.81920111e-01, -2.47785434e-01,
#        -2.05592930e-01, -3.37042600e-01, -2.03586549e-01, -2.61086132e-02,
#        -1.10088624e-01,  5.90005398e-01,  1.39311543e-02,  2.95088261e-01,
#         8.70520342e-03,  3.30439955e-03, -2.29388684e-01,  2.87119269e-01],
#       dtype=float32)

# %%
for row in test_seq_df.iter_tuple():
    row = getattr()

# %% [markdown]
# # Performance Metrics

# %%
def _compute_precision_recall(targets, predictions, k):
		"""
		targets : 실제 관심 있는 item list 
		predictions : prob sorted in descending order.
    """
    pred = predictions[:k]
    num_hit = len(set(pred).intersection(set(targets))) #  hit는 k개 추천 아이템 중에 사용자가 실제로 관심 있는 상품이 존재하는 경우를 의미하며, = TP
    precision = float(num_hit) / len(pred)
    recall = float(num_hit) / len(targets)
    return precision, recall

def ap(rel_items, recc_items, k=5):
    precisions = []
    for i in range(k):
        k_recc = recc_items[:i+1]
        n_hits = set(rel_items) & set(recc_items)
        rel = recc_items[i] in rel_item #1/0
        precisions.append(len(n_hits)/len(rel_items)*rel))
    ap_k = sum(precisions) / len(precisions)
    return ap_k

def map(k=5):
    for
